# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv('global_student_digital_behavior_dataset.csv', index_col= 'student_id')
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 360184 entries, 1 to 360184
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   country                         360184 non-null  str
#  1   development_level               360184 non-null  str
#  2   poverty_rate_percent            360184 non-null  float64
#  3   internet_infrastructure_index   360184 non-null  float64
#  4   average_internet_speed_mbps     360184 non-null  float64
#  5   age                             360184 non-null  int64
#  6   gender                          360184 non-null  str
#  7   urban_rural                     360184 non-null  str
#  8   family_income_level             360184 non-null  str
#  9   device_access                   360184 non-null  str
#  10  internet_access_hours           360184 non-null  float64
#  11  education_level                 360184 non-null  str
# ...

# %% [markdown]
# ##### Fillin values in columns who have nan values more the 1000

# %%
df['brain_rot_level'] = df['brain_rot_level'].fillna('NA')
df['field_of_study'] = df['field_of_study'].fillna('NA')

# %% [markdown]
# dropping nan values in column whom have under 10 nan values

# %%
df = df.dropna().reset_index()
df = df.set_index('student_id')
df.isnull().sum()
# Out:
# country                           0
# development_level                 0
# poverty_rate_percent              0
# internet_infrastructure_index     0
# average_internet_speed_mbps       0
# age                               0
# gender                            0
# urban_rural                       0
# family_income_level               0
# device_access                     0
# internet_access_hours             0
# education_level                   0
# field_of_study                    0
# academic_motivation               0
# online_learning_hours             0
# social_media_hours                0
# sessions_per_day                  0
# average_session_length_minutes    0
# late_night_usage                  0
# education_content_hours           0
# short_video_hours                 0
# entertainment_content_hours       0
# news_content_hours                0
# likes_given_per_day               0
# comments_written_per_day          0
# posts_created_per_week            0
# ...

# %% [markdown]
# mapping ordinal data/ to reduce redundance

# %%
brain_map = {'Low':1, 'Moderate':2, 'NA':0}

late_night = {'Sometimes': 2, 'Often': 3, 'Never': 1, 'Always': 4}

yes_no = {'Yes': 1,'No': 0}

df['brain_rot_level'] = df['brain_rot_level'].map(brain_map)
df['late_night_usage'] = df['late_night_usage'].map(late_night)
df['cyberbullying_exposure'] = df['cyberbullying_exposure'].map(yes_no)
df['adult_content_exposure'] = df['adult_content_exposure'].map(yes_no)

# %% [markdown]
# converting data into relevent data type for better memory optimization

# %%
column_to_category = ["country","development_level","gender",
    "urban_rural","family_income_level",
    "device_access",
    "education_level",
    "field_of_study"]

df[column_to_category]= df[column_to_category].astype('category')

column_to_int8 = ["brain_rot_level","late_night_usage",
    "late_night_score",
    "adult_content_exposure",
    "cyberbullying_exposure",
    "age"]

df[column_to_int8]= df[column_to_int8].astype('int8')

columns_to_clean = ["poverty_rate_percent","internet_infrastructure_index",
    "average_internet_speed_mbps","internet_access_hours",
    "academic_motivation","online_learning_hours",
    "social_media_hours","sessions_per_day","average_session_length_minutes",
    "education_content_hours","short_video_hours","entertainment_content_hours",
    "news_content_hours","likes_given_per_day",
    "comments_written_per_day","posts_created_per_week",
    "brain_rot_index","attention_span_minutes","study_hours_per_week",
    "class_attendance_rate","productivity_score","sleep_hours",
    "stress_level","anxiety_score","depression_score","ads_clicked_per_week",
    "ads_viewed_per_day","impulse_purchase_score","digital_spending_per_month",
    "digital_addiction_score",
    "wellbeing_index",
    "academic_risk_score",
    "financial_risk_score"]

df[columns_to_clean]= df[columns_to_clean].round(3).astype('float32')


df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 360183 entries, 1 to 360183
# Data columns (total 47 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   country                         360183 non-null  category
#  1   development_level               360183 non-null  category
#  2   poverty_rate_percent            360183 non-null  float32
#  3   internet_infrastructure_index   360183 non-null  float32
#  4   average_internet_speed_mbps     360183 non-null  float32
#  5   age                             360183 non-null  int8
#  6   gender                          360183 non-null  category
#  7   urban_rural                     360183 non-null  category
#  8   family_income_level             360183 non-null  category
#  9   device_access                   360183 non-null  category
#  10  internet_access_hours           360183 non-null  float32
# ...

# %% [markdown]
# exporting file

# %%
df.to_csv('clean_global_student_digital_behavior.csv')
